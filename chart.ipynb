# %%
from sim.Plotchart import *

folder_name = 'results/ONP_SFO/420_1040_1020_800_seed2405/'
dir = [["limited/cent_1_event.csv", "limited/dist_1_event.csv"],
        ["limited/cent_2d_event.csv", "limited/dist_2d_event.csv"],
        ["limited/cent_2n_event.csv", "limited/dist_2n_event.csv"],
        ["limited/cent_2i_event.csv", "limited/dist_2i_event.csv"],
        ["inf/cent_1_event.csv", "inf/dist_1_event.csv"]
]
label = [["ONP_SFO cent", "ONP_SFO dist"],
        ["ONP_SFO cent + remap", "ONP_SFO dist + remap"],
        ["ONP_SFO cent + nosort", "ONP_SFO dist + nosort"],
        ["ONP_SFO cent + remap incr", "ONP_SFO dist + remap incr"],
        ["ONP_SFO cent inf", "ONP_SFO dist inf"]
]
chart = Chart(folder_name,dir,label)
paper_input = [0, 1, 2, 3]
all_input = [0, 1, 2, 3, 4, 5, 6, 7]

chart.Acceptance(round=False)
chart.Utilization(round=False)
chart.Power(data_id=all_input)
chart.PowerPerSFC(data_id=all_input)
chart.ActiveServer(all_input)
